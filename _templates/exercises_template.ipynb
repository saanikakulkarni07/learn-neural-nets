# %% [markdown]
# # Chapter N — Exercises
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saanikakulkarni07/learn-neural-nets/blob/main/chNN-slug/exercises.ipynb)
#
# _Companion to my notes for this chapter. Work top to bottom._

# %%
# Colab setup — run me first.
# The book ships a tiny helper package (datasets + reproducible init).
# !pip install nnfs -q
import numpy as np
import matplotlib.pyplot as plt
import nnfs
nnfs.init()  # sets seed + default dtype for reproducibility

# %% [markdown]
# ## Concept check
#
# > ✏️ *Question goes here.*
#
# _Your answer:_

# %% [markdown]
# ## Exercise 1 — <title>
#
# **Task:** ...

# %%
# your code here

# %% [markdown]
# ## 🔭 Astro bonus
#
# **Task:** ...

# %%
# your code here
